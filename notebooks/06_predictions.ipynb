# %% [markdown]
# # Predictions for All Sets
# Generate predictions for Set 1, Set 2, and Set 3 and visualize MUSIC peaks.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
sys.path.append(str(ROOT))

from src.deployment.inference import run_predictions

model_path = ROOT / "outputs" / "models" / "best_model.pt"
if not model_path.exists():
    model_path = ROOT / "outputs" / "models" / "best_model_nb.pt"

outputs = run_predictions(model_path)
print("Saved predictions to outputs/logs/predictions.json")
for set_name, items in outputs.items():
    print(set_name, "count:", len(items))
